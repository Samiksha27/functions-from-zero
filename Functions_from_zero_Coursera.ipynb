# %% [markdown]
# <a href="https://colab.research.google.com/github/Samiksha27/functions-from-zero/blob/main/Functions_from_zero_Coursera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
